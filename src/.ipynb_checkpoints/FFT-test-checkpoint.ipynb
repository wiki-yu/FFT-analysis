# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft
from scipy.stats import kstest,ks_2samp
from statsmodels.distributions.empirical_distribution import ECDF

# %%
data = pd.read_excel('../data/point10.xlsx')

# %%
data.head()
# Out:
#             TimeStamp  Channel00  Channel01  Channel02  Channel03  Channel04  \
# 0  131340711763480000   0.166994  -0.347784  -0.017747   0.054243   0.003948
# 1  131340711763490000   0.165022  -0.348113  -0.019062   0.083170   0.004606
# 2  131340711763500000   0.165022  -0.344497  -0.018405   0.088759   0.006249
# 3  131340711763510000   0.165680  -0.342196  -0.017090   0.086129   0.012824
# 4  131340711763520000   0.168638  -0.342853  -0.023007   0.066406   0.015454
#
#    Channel05  Channel06  Channel07  Channel08  ...  Channel11  Channel12  \
# 0   0.009208  -0.025965   0.039779  -0.008214  ...  -0.050620   0.103551
# 1   0.010194  -0.025965   0.038135  -0.005256  ...  -0.051277   0.089416
# 2   0.011509  -0.027280   0.035177   0.006249  ...  -0.051934   0.087772
# 3   0.004934  -0.026623   0.033205   0.003948  ...  -0.045360   0.080541
# 4   0.007236  -0.024651   0.038464  -0.001640  ...  -0.050948   0.080541
#
# ...

# %%
data.describe()
# Out:
#           TimeStamp     Channel00     Channel01     Channel02     Channel03  \
# count  1.080000e+04  10800.000000  10800.000000  10800.000000  10800.000000
# mean   1.313407e+17      0.056064     -0.006762     -0.018819     -0.034100
# std    3.117836e+07      0.191395      0.523222      0.009039      0.114585
# min    1.313407e+17     -0.404324     -0.774465     -0.057523     -0.744880
# 25%    1.313407e+17     -0.055879     -0.333731     -0.023336     -0.059824
# 50%    1.313407e+17      0.001976     -0.075274     -0.018734     -0.033526
# 75%    1.313407e+17      0.150558      0.091060     -0.014131     -0.014131
# max    1.313407e+17      0.914180      1.991403      0.028931      1.187677
#
#           Channel04     Channel05     Channel06     Channel07     Channel08  \
# count  10800.000000  10800.000000  10800.000000  10800.000000  10800.000000
# mean       0.004927      0.012076     -0.027062      0.027662      0.018009
# ...

# %%
abl_p = data.iloc[:, 12:13]
abl_d = data.iloc[:, 13:14]
cs_p = data.iloc[:, 4:5]
signal_1 = abl_p.values
signal_2 = cs_p.values

# %%
signal_1 = signal_1.ravel()
signal_2 = signal_2.ravel()

# %%
def oneD_fft(signal):
    N = len(signal) # Number of sample points
    T = 0.001  # sample spacing
    print(N)
    # x_base = np.linspace(0, N*T, N)
    signal = signal - np.mean(signal)
    fft_val = fft(signal)
    x_axis = np.linspace(0.0, 1.0 / (2.0 * T), N // 2)
    y_axis = 2 / N * np.abs(fft_val[0: N // 2])
    plt.figure()
    plt.plot(x_axis, y_axis)
    plt.grid()
    plt.show
    return y_axis

# %%
def ks_test(fft_signal_1, fft_signal_2):
    stat = ks_2samp(fft_signal_1, fft_signal_2)
    ecdf1, ecdf2 = ECDF(fft_signal_1), ECDF(fft_signal_2)
    fig = plt.figure()
    xs = np.linspace(min(fft_signal_1 + fft_signal_2), 
                     max(fft_signal_1 + fft_signal_2), 
                     num=10000)
    #plt.figure(figsize=(12,8))
    plt.plot(xs, ecdf1(xs), xs, ecdf2(xs))
    plt.show()
    return stat

# %%
signal_1 = signal_1[:4096:2]
signal_2 = signal_2[:4096:2]
fft_signal_1 = oneD_fft(signal_1)
fft_signal_2 = oneD_fft(signal_2)
stat = ks_test(fft_signal_1, fft_signal_2)
stat
# Out:
# 2048
# 2048
# Ks_2sampResult(statistic=0.876953125, pvalue=0.0)
